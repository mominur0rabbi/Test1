# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Studata.csv')

# %%
df.head()
# Out:
#    CollegeId Profession WhichPlaceChildLive WhoDoesYurChildStay  \
# 0          1        JOB        OtherDistUPJ              Mother
# 1          2        JOB         DnjOtherUPJ             Parents
# 2          3        JOB         DnjOtherUPJ             Parents
# 3          4       AGRI            Dinajpur                Mess
# 4          5        JOB         DnjOtherUPJ             Parents
#
#   TypeTVChildWatch ChildUsesNetMedium SocialMedia DeviceUseOnlineClass  \
# 0              LED              NoUse    Facebook          MobilePhone
# 1          General         MobileData    Facebook          MobilePhone
# 2              LED         MobileData    Facebook          MobilePhone
# 3          Android         MobileData    Facebook          MobilePhone
# 4          SmartTV         MobileData    Facebook          MobilePhone
#
#   OthersWorksOnlineOutsideOnlineClass KindProblemDoingOnlineClasses  \
# 0                         Facebooking                   SlowNetwork
# ...

# %%
df.describe(include="all")
# Out:
#                 ID  Pro   Q1   Q2   Q3   Q4   Q5   Q6   Q7   Q8   Q9
# count   199.000000  199  199  199  199  199  199  199  199  199  199
# unique         NaN    5    6    6    6    4    5    5    6    5    6
# top            NaN  JOB    A    C    A    A    A    B    A    A    B
# freq           NaN  115   57  153   90  133  155  170  103  136  110
# mean    257.814070  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# std     244.280702  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# min       1.000000  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 25%      88.500000  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 50%     205.000000  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75%     330.500000  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# max     944.000000  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Holy Land College, Online Class Related Report", explorative=True)

# %%
profile.to_file(output_file="Studata.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
